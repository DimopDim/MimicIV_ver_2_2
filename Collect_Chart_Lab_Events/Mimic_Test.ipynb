# %%
import gzip
import pandas as pd
import warnings
import gc

# %%
# Read the exported for header chartevent CSV file
head_df = pd.read_csv('CSV\Exports\datasets\whole_set\o01_final_mean_table.csv')

# %%
display(head_df)
# Out:
#        row_count  subject_id   hadm_id  Time_Zone gender  age language  \
# 0              1    10001884  26184834          1      F   77  ENGLISH
# 1              2    10001884  26184834          2      F   77  ENGLISH
# 2              3    10001884  26184834          3      F   77  ENGLISH
# 3              4    10001884  26184834          4      F   77  ENGLISH
# 4              5    10001884  26184834          5      F   77  ENGLISH
# ...          ...         ...       ...        ...    ...  ...      ...
# 64571      64572    19996783  21880161         12      M   89        ?
# 64572      64573    19996783  21880161         13      M   89        ?
# 64573      64574    19996783  21880161         14      M   89        ?
# 64574      64575    19996783  21880161         15      M   89        ?
# 64575      64576    19996783  21880161         16      M   89        ?
#
#       marital_status                    race  Base Excess - Mean  ...  \
# ...
