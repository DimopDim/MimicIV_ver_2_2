# %%
import pandas as pd
# Set the display option to show all columns
pd.set_option('display.max_columns', None)

# %%
# Read the files `d_items.csv`
compressed_chart_items_df = r"..\Datasets\mimic-iv-2_2\icu\d_items.csv.gz"
compressed_lab_items_df = r"..\Datasets\mimic-iv-2_2\hosp\d_labitems.csv.gz"

# Read and pass the compressed CSV file into a DataFrame
chart_items_df = pd.read_csv(compressed_chart_items_df, compression='gzip')
lab_items_df = pd.read_csv(compressed_lab_items_df, compression='gzip')

# %%
# Extracting the column headers
mimic_headers = mimic_df.columns.tolist()

# %%
lab_chart_temp_df = pd.read_csv('CSV\Exports\o04_icu_chart_lab_merged.csv')
# Out:
# C:\Users\dimop\AppData\Local\Temp\ipykernel_22940\3177034828.py:1: DtypeWarning: Columns (9,21,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   lab_chart_temp_df = pd.read_csv('CSV\Exports\o04_icu_chart_lab_merged.csv')

# %%
temp_df = lab_chart_temp_df[lab_chart_temp_df['itemid'] == 51009]

# %%
display(temp_df)
# Out:
#           subject_id   hadm_id   stay_id                      first_careunit  \
# 20321       10005817  28661809  31316840  Medical Intensive Care Unit (MICU)
# 20322       10005817  28661809  31316840  Medical Intensive Care Unit (MICU)
# 20323       10005817  28661809  31316840  Medical Intensive Care Unit (MICU)
# 20324       10005817  28661809  31316840  Medical Intensive Care Unit (MICU)
# 20325       10005817  28661809  31316840  Medical Intensive Care Unit (MICU)
# ...              ...       ...       ...                                 ...
# 12693315    19985409  27293537  32597806                  Neuro Intermediate
# 12693316    19985409  27293537  32597806                  Neuro Intermediate
# 12696215    19989918  22474537  30333293                 Trauma SICU (TSICU)
# 12698280    19990427  29695607  34058245                 Trauma SICU (TSICU)
# 12704656    19991135  29872770  33242276  Medical Intensive Care Unit (MICU)
#
# ...

# %%
display(lab_chart_temp_df)
# Out:
#           subject_id   hadm_id   stay_id                      first_careunit  \
# 0           10001884  26184834  37510196  Medical Intensive Care Unit (MICU)
# 1           10001884  26184834  37510196  Medical Intensive Care Unit (MICU)
# 2           10001884  26184834  37510196  Medical Intensive Care Unit (MICU)
# 3           10001884  26184834  37510196  Medical Intensive Care Unit (MICU)
# 4           10001884  26184834  37510196  Medical Intensive Care Unit (MICU)
# ...              ...       ...       ...                                 ...
# 12715931    19996783  21880161  31700331            Coronary Care Unit (CCU)
# 12715932    19996783  21880161  31700331            Coronary Care Unit (CCU)
# 12715933    19996783  21880161  31700331            Coronary Care Unit (CCU)
# 12715934    19996783  21880161  31700331            Coronary Care Unit (CCU)
# 12715935    19996783  21880161  31700331            Coronary Care Unit (CCU)
#
# ...

# %%
row_temp_df = pd.read_csv('CSV\Exports\o07_chartevent_rows.csv')

# %%
display(row_temp_df)

# %%
lab_df = lab_items_df[lab_items_df['label'] == 'Vancomycin']

# %%
display(lab_df)
# Out:
#      itemid       label  fluid   category
# 205   51009  Vancomycin  Blood  Chemistry

# %%
display(lab_chart_temp_df)

# %%
final_df = pd.read_csv('CSV\Exports\datasets\whole_set\o01_final_mean_table.csv')

# %%
# Extract the specific column
temp_column = final_df[['Vancomycin - Mean']]

# %%
# Count not NaN
non_nan_count = temp_column['Vancomycin - Mean'].count()

# Count NaN
nan_count = temp_column['Vancomycin - Mean'].isna().sum()

print ('non nan are: ', non_nan_count)
print ('nan are: ', nan_count)
